# %% [markdown]
# <a href="https://colab.research.google.com/github/alzoubishoruq9-AI/conversation-agent-/blob/main/conversation_agent_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain

# %%
# !pip install python-dotenv

# %%
# !pip install langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 477.4/477.4 kB 14.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.1
#     Uninstalling langchain-core-1.2.1:
#       Successfully uninstalled langchain-core-1.2.1
# ...

# %%
# !pip install langchain-tools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.chat_history import ChatMessageHistory
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-859160221.py in <cell line: 0>()
#       4 from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder
#       5 from langchain_core.runnables.history import RunnableWithMessageHistory
# ----> 6 from langchain_core.chat_history import ChatMessageHistory
#
# ImportError: cannot import name 'ChatMessageHistory' from 'langchain_core.chat_history' (/usr/local/lib/python3.12/dist-packages/langchain_core/chat_history.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
load_dotenv()
os.environ["OPEN_API_KEY"]=os.getenv("OPEN_API_KEY")
llm=ChatOpenAI(model="gpt-4o-mini",max_tokens=1000,temperature=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3445240407.py in <cell line: 0>()
#       1 load_dotenv()
# ----> 2 os.environ["OPEN_API_KEY"]=os.getenv("OPEN_API_KEY")
#       3 llm=ChatOpenAI(model="gpt-4o-mini",max_tokens=1000,temperature=0)
#       4
#
# /usr/lib/python3.12/os.py in __setitem__(self, key, value)
#
# /usr/lib/python3.12/os.py in encode(value)
#
# TypeError: str expected, not NoneType

# %%
store={}
def get_chat_history(session_id:str):
  if session_id not in store:
    store[session_id]=ChatMessageHistory()
  return store[session_id]

# %%
prompt=ChatPromptTemplate.from_messages([
    ('system','you are a helpful AI assistant.'),
    MessagesPlaceholder(variable_name="history"),
    ('human','{input}')


])

# %%
chain=prompt|llm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3323120463.py in <cell line: 0>()
# ----> 1 chain=prompt|llm
#
# NameError: name 'llm' is not defined

# %%
chain_with_history=RunnableWithMessageHistory(
    chain,
    get_chat_history,
    history_messages_key="history",
    input_messages_key="input"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2605928507.py in <cell line: 0>()
#       1 chain_with_history=RunnableWithMessageHistory(
# ----> 2     chain,
#       3     get_chat_history,
#       4     history_messages_key="history",
#       5     input_messages_key="input"
#
# NameError: name 'chain' is not defined

# %%
session_id="user_123"

response1=chain_with_history.invoke(
    {"input":"HI HOW ARE YOU?"},
    config={"configurable":{"session_id":session_id}})
print("AI:",response1.content)
response2=chain_with_history.invoke(
    {"input":"im so funny you can feel it "},
    config={"configurable":{"session_id":session_id}}

)
print ("AI",response2.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2301985126.py in <cell line: 0>()
#       1 session_id="user_123"
#       2
# ----> 3 response1=chain_with_history.invoke(
#       4     {"input":"HI HOW ARE YOU?"},
#       5     config={"configurable":{"session_id":session_id}})
#
# NameError: name 'chain_with_history' is not defined

# %%
print("\nConversational Histort")
for message in store[session_id].messages:
  print(f"{message.type}:{message.content}")
# Out:
# Conversational Histort
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2244578946.py in <cell line: 0>()
#       1 print("\nConversational Histort")
# ----> 2 for message in store[session_id].messages:
#       3   print(f"{message.type}:{message.content}")
#       4
#
# KeyError: 'user_123'
